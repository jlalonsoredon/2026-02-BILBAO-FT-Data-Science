# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics I

# %% [markdown]
# ## Ejercicio 0
# Imprime por pantalla esta cita con el siguiente formato
#
# ![imagen](./img/frase_Einstein.PNG)

# %%
print("¿por qué esta magnifica tecnología científica, \n\tque ahorra trabajo y nos hace la vida más fácil, \n\t\tnos aporta tan poca felicidad? \n\t\t\t\tLa respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.\n\"Albert Einstein\"")
# Out:
# ¿por qué esta magnifica tecnología científica,
# 	que ahorra trabajo y nos hace la vida más fácil,
# 		nos aporta tan poca felicidad?
# 				La respuesta es está, simplemente: porque aún no hemos aprendido a usarla con tino.
# "Albert Einstein"

# %% [markdown]
# ## Ejercicio 1
# 1. Escribe el nombre de la calle de tu domicilio en una variable
# 2. Escribe el numero de la calle en otra
# 3. Ciudad en una tercera
# 4. Codigo postal en la cuarta variable
# 5. Imprime las 4 variables concatenadas por pantalla
# 6. Crea una quinta variable que concatene todas ellas
# 7. Imprímela por pantalla

# %%
calle = "Tabira"
numero = "10"
poblacion = "Bilbao"
cp = "48200"
print(calle, numero, poblacion, cp)
direccion = calle + " " + numero + ", " + cp + " " + poblacion
print(direccion)
# Out:
# Tabira 10 Bilbao 48200
# Tabira 10, 48200 Bilbao

# %% [markdown]
# ## Ejercicio 2
# Repite el ejercicio 1, pero pidiendo estos datos al usuario mediante un input(), imprimiendo a continuación la dirección completa

# %%
calle = input("Introduce el nombre de la calle: ")
numero = input("Introduce el número de la calle: ")
poblacion = input("Introduce el nombre de la población: ")
cp = input("Introduce el código postal: ")
direccion = calle + " " + numero + ", " + cp + " " + poblacion
print(direccion)
# Out:
# gran via 2, 48001 Bilbao

# %% [markdown]
# ## Ejercicio 3
# ¿Qué variables están mal escritas y por qué? Realiza primero tu hipótesis y luego ejecuta las variables para comprobarlo. En ese orden :)
#
#
# 1. mi_variable = "Economía"
# 2. otra_var = "Ejercicio
# 3. True = "Ejercicio"
# 4. mi variab1e = "Alpha"
# 5. import = 40
# 6. 81mi_variable = "Agua"
# 7. mi_variable10 = 6

# %%
True = "Ejercicio"  # No se puede usar como variable porque es una palabra reservada
4. mi variab1e = "Alpha" # No se puede usar como variable porque no puede contener espacios
5. import = 40 # No se puede usar como variable porque es una palabra reservada
6. 81mi_variable = "Agua" # No se puede usar como variable porque no puede empezar con un número
# Out:
#   Cell In[3], line 4
#     6. 81mi_variable = "Agua" # No se puede usar como variable porque no puede empezar con un número
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ## Ejercicio 4
# Realiza un conversor de grados Celsius a Fahrenheit. El conversor tiene que recibir el input del usuario y devolver la conversión.
#
# La conversión de grados sigue la siguiente fórmula: F = C × (9 / 5) + 32

# %%
grados_celsius = (float(input("Introduce la temperatura en grados Celsius: ")))
grados_fahrenheit = (grados_celsius * 9/5) + 32
print(f"{grados_celsius} grados Celsius son {grados_fahrenheit} grados Fahrenheit.")
# Out:
# 20.0 grados Celsius son 68.0 grados Fahrenheit.

# %% [markdown]
# ## Ejercicio 5
# Comenta  el Ejercicio 4. Pon un comentario multilinea y haz comentarios de cada linea de código

# %%
'''
Aplicación que convierte de grados centigrados
a grados Fahrenheit.
a partir de un input que rellena el usuario
con grados centigrados.
'''
#imprme el input al usuario y recoge el dato como string
grados_celsius_string = (input("Introduce la temperatura en grados Celsius: "))
#intenta convertir el string a float y realizar la conversión
# Si se puede convertir, se realiza la conversión y se imprime el resultado
try:
    grados_celsius = float(grados_celsius_string)
    #formula que realiza la conversión
    grados_fahrenheit = (grados_celsius * 9/5) + 32
    #imprime en pantalla el resultado formateado
    print(f"{grados_celsius} grados Celsius son {grados_fahrenheit} grados Fahrenheit.")
# Si no se puede convertir, se captura la excepción y se muestra un mensaje de error
except ValueError:
    #imprime un mensaje de error personalizado
    print("Error: entrada no válida. Por favor, introduce un número válido.")
    #termina la ejecución del programa.
    exit(1)
# Out:
# 20.4 grados Celsius son 68.72 grados Fahrenheit.
