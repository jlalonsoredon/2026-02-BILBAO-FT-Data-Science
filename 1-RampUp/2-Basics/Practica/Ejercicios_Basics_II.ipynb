# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # Ejercicios Python Basics II

# %% [markdown]
# ## Ejercicio 1
# * Crea dos variables numericas: un `int` y un `float`
# * Comprueba sus tipos
# * Sumalas en otra nueva
# * ¿De qué tipo es la nueva variable?
# * Elimina las variables creadas

# %%
num_entero = 10
num_decimal = 3.14
print("num_entero:", num_entero, "tipo:", type(num_entero))
print("num_decimal:", num_decimal, "tipo:", type(num_decimal))
suma = num_entero + num_decimal
print("resultado suma:", suma, "tipo:", type(suma))
del num_entero
del num_decimal
del suma

# %% [markdown]
# ## Ejercicio 2
# Escribe un programa para pasar de grados a radianes. Hay que usar `input`. Recuerda que la conversión se realiza mediante
#
# $$radianes = grados*(pi/180)$$

# %%
import math
PI = math.pi
grados_text = input("Introduce la temperatura en grados Celsius: ")
grados = grados_text.replace(",", ".")  # Reemplaza la coma por un punto si el usuario la usó
try:
    grados = float(grados)
    radianes = grados * (PI / 180)
    print(f"{grados} grados Celsius son {radianes} radianes.")
except ValueError:
    print("Error: Por favor, introduce un número válido para los grados Celsius.")

# %% [markdown]
# ## Ejercicio 3
# Escribe un programa que calcule el area de un paralelogramo (base x altura). También con `input`

# %%
def calcular_area(base, altura):
    area = (base * altura) / 2
    return area

try:
    base = input("Introduce la base del triángulo: ")
    base = base.replace(",", ".")
    base = float(base)
    
    if base <= 0:
        raise ValueError("La base debe ser un número positivo.")
    
    altura = input("Introduce la altura del triángulo: ")
    altura = altura.replace(",", ".")
    altura = float(altura)
    
    if altura <= 0:
        raise ValueError("La altura debe ser un número positivo.")
    
    area = calcular_area(base, altura)
    print(f"El área del triángulo con base {base} y altura {altura} es: {area}")

except ValueError as e:
    print(f"Error: {e}")

# %% [markdown]
# ## Ejercicio 4
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1
print(A == B)
print(A != C)
print(A > C)
print(C <= A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ## Ejercicio 5
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
a = input("Introduce un dato: ")
b = input("Introduce otro dato: ")
if a == b:
    print("Los datos son iguales.")
else:    
    print("Los datos son diferentes.")
# Out:
# Los datos son diferentes.

# %% [markdown]
# ## Ejercicio 6
# Mismo programa que en 5, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
a = input("Introduce un dato: ")
b = input("Introduce otro dato: ")
c = input("Introduce un tercer dato: ")
if a == b == c:
    print("Los datos son iguales.")
elif a == b or a == c or b == c:
    print("Al menos dos datos son iguales.")
else:    
    print("Los datos son diferentes.")
# Out:
# Al menos dos datos son iguales.

# %% [markdown]
# ## Ejercicio 7
# Crea un programa que recoja dos inputs. Tiene que comprobar si su suma es igual, superior o inferior a 10, cada condición por separado

# %%
num_a = input("Introduce un número: ")
num_b = input("Introduce otro número: ")

try:
    num_a = float(num_a.replace(",", "."))
    num_b = float(num_b.replace(",", "."))
    
    suma = num_a + num_b
    
    if suma > 10:
        print(f"La suma de {num_a} y {num_b} es mayor que 10.")
    elif suma < 10:
        print(f"La suma de {num_a} y {num_b} es menor que 10.")
    else:
        print("La suma de los números es igual a 10.")
except ValueError:
    print("Error: Por favor, introduce números válidos.")
# Out:
# La suma de 7.0 y 5.0 es mayor que 10.

# %% [markdown]
# ## Ejercicio 8
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True
#
# Compruébalo después con python

# %% [markdown]
# 1. False
# 2. not (True) and (True) = False and True = False
# 3. True and False = False
# 4. True and True and False = False

# %%
print(True and True and False)                      #Es una contatenación de ANDs por lo que con que haya un False el resultado es FALSE

print(not ((True or False) and (True or False)))    #(True or False) es True, (True or False) es True, entonces (True and True) es True
                                                    #, y el not de True es FALSE
                                                    
print((False or False or False or True) and False)  #(False or False or False Or True)Es una concatenación de ORs 
                                                    #por lo que con que haya un True el resultado es True, 
                                                    #entonces (True and False) es FALSE 
                                                    
print(not False and True and not True)              #not False es True, not True es False, 
                                                    #entonces (True and True and False) al ser uns concatenación de ANDs y 
                                                    # tener un False el resultado es FALSE
# Out:
# False
# False
# False
# False

# %% [markdown]
# ## Ejercicio 9
# Para este ejercicio vamos a poner en práctica [las funciones built in](https://docs.python.org/3/library/functions.html).
#
# 1. Calcula el máximo de la lista: [4, 6, 8, -1]
# 2. Suma todos los elementos de la lista anterior
# 3. Redondea este float a 3 dígitos decimales: 63.451256965
# 4. Valor absoluto de: -74

# %%
list = [4, 6, 8, -1]
print(max(list))
print(sum(list))
num_real  = 63.451256965
print(round(num_real, 3))
print(abs(-74))
# Out:
# 8
# 17
# 63.451
# 74

# %% [markdown]
# ## Ejercicio 10
# Para el siguiente string se pide imprimir por pantalla los siguientes casos
#
#     "Lo primero de todo, cómo están los máquinas"
#
# 1. Pasarlo todo a mayúsculas
# 2. Pasarlo todo a minúsculas
# 3. Pasar a mayúsculas solo las iniciales de las palabras
# 4. Crea una lista dividiendolo por sus espacios
# 5. Sustituye las comas `,` por puntos y comas `;`
# 6. Elimina las `a` minúsculas

# %%
text = "Lo primero de todo, cómo están los máquinas"
print(text.upper())
print(text.lower())
print(text.capitalize())
list = text.split(" ")
print(list)
print(text.replace(",", ";"))
print(text.replace("a", ""))
# Out:
# LO PRIMERO DE TODO, CÓMO ESTÁN LOS MÁQUINAS
# lo primero de todo, cómo están los máquinas
# Lo primero de todo, cómo están los máquinas
# ['Lo', 'primero', 'de', 'todo,', 'cómo', 'están', 'los', 'máquinas']
# Lo primero de todo; cómo están los máquinas
# Lo primero de todo, cómo están los máquins

# %% [markdown]
# ## Ejercicio 11
# 1. Crea una lista con 3 elementos numéricos
# 2. Añade un cuarto elemento
# 3. Calcula la suma de todos
# 4. Elimina el segundo elemento de la lista
# 5. Añade otro elemento en la posicion 3 de la lista
# 6. Crea otra lista con 4 elementos y concaténala a la que ya tenías.

# %%
nums_list = [1, 2, 3]
print(nums_list)
nums_list.append(4)
print(nums_list)
print(sum(nums_list))
nums_list.pop(1)
print(nums_list)
nums_list.insert(2, 5)
print(nums_list)
nums_list2= [6, 7, 8, 9]
print(nums_list +nums_list2)
# Out:
# [1, 2, 3]
# [1, 2, 3, 4]
# 10
# [1, 3, 4]
# [1, 3, 5, 4]
# [1, 3, 5, 4, 6, 7, 8, 9]
