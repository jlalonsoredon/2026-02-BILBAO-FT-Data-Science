# %% [markdown]
# ## Ejercicio descargas

# %% [markdown]
# Python es un lenguaje de propósito general, por lo que podemos desarrollar otros programas,
# aparte de ciencia de datos, que nos permitan montar dashboards, crear APIs o automatizar
# procesos. En este caso vas a automatizar un proceso, en el que tendrás que desarrollar un
# script que ordene todos los archivos de una carpeta, dependiendo de la extensión de los
# mismos.
#
#
# El objetivo es ordenar la típica carpeta de cajón desastre donde se nos acumulan archivos de
# todos los formatos como: imágenes, words, presentaciones, excels, ejecutables, zips, etc... Y
# que no vamos a ir viendo archivo a archivo, ordenándolos.... La solución suele ser eliminarlo
# todo. Vamos a intentar no tener que llegar a eso, ordenando los ficheros automáticamente en
# carpetas y revisar las que nos interesen. La típica carpeta donde aplicaríamos este programa es
# la de “Descargas”, donde se suelen acumular muchos archivos temporales.
#
#
# Por tanto, **el programa tiene que guardar los archivos de la carpeta “Descargas” (o cualquier
# otra donde acumules mucho archivo temporal) en los siguientes directorios dentro de la
# propia carpeta “Descargas”**:
# - Imagenes
# - Documentos
# - Software
# - Otros
#
# Cada vez que ejecutes el script, automáticamente se ordenarán todos los archivos en sus
# correspondientes carpetas.

# %%
doc_types = ('.doc', '.docx', '.txt', '.pdf', '.xls', '.ppt', '.xlsx', '.pptx')
img_types = ('.jpg', '.jpeg', '.png', '.svg', '.gif')
software_types = ('.exe', '.py','.ipynb')

# %% [markdown]
# ### 1. Crea un un programa con el flujo principal y encapsúlalo en funciones.

# %%
import os
import shutil

# %%
os.getcwd()
os.chdir('C:\\Users\\jlalo\\Downloads')
os.chdir('..\\')
print(os.getcwd())
#copy Downloads folder
if not os.path.exists('Desktop\\Downloads_backup'):
    shutil.copytree('Downloads', 'Desktop\\Downloads_backup')
os.chdir('Desktop\\Downloads_backup')
os.listdir()
# Out:
# C:\Users\jlalo
# ['dataset',
#  'ejecutables',
#  'excels',
#  'imágenes',
#  'Jupyter_Notebooks',
#  'LibreOffice_26.2.1_Win_x86-64.msi',
#  'listings (1).csv',
#  'presentaciones',
#  'txts',
#  'words',
#  'zips']

# %%
folders = ['imágenes', 'words', 'presentaciones', 'excels', 'ejecutables', 'zips', 'dataset', 'Jupyter_Notebooks', "txts"]

def create_folder(list_folders):
    for folder in list_folders:
        if not os.path.exists(folder):
            os.makedirs(folder)

create_folder(folders)

# %%
os.getcwd()
# Out:
# 'C:\\Users\\jlalo\\Desktop\\Downloads_backup'

# %%
result_generator = os.walk(os.getcwd())

def get_extension(file_name):
    return os.path.splitext(file_name)[1].lower()


def move_file(root, file, folder):
    shutil.move(os.path.join(root, file), os.path.join(os.getcwd(), folder, file))

def sort_files(result_generator):
    for root, dirs, files in result_generator:
        for file in files:
            if '.' in file:
                extension = get_extension(file)
                match extension:
                    case ".exe" | ".msi" | ".bat" | ".sh" | ".py":
                        move_file(root, file, 'ejecutables')
                    case ".zip" | ".rar" | ".tar" | ".gz":
                        move_file(root, file, 'zips')
                    case ".jpg" | ".jpeg" | ".png" | ".svg" | ".gif" | ".bmp" | ".tiff" | ".webp":
                        move_file(root, file, 'imágenes')
                    case ".doc" | ".docx":
                        move_file(root, file, 'words')
                    case ".txt" | ".md":
                        move_file(root, file, 'txts')
                    case ".xls" | ".xlsx":
                        move_file(root, file, 'excels')
                    case ".ppt" | ".pptx" | ".pdf":
                        move_file(root, file, 'presentaciones')
                    case ".csv" | ".json" | ".xml":
                        move_file(root, file, 'dataset')
                    case ".ipynb":
                        move_file(root, file, 'Jupyter_Notebooks')
                    case _:
                        print(f"Archivo {file} con extensión {extension} no categorizado.")

sort_files(result_generator)
# Out:
# .msi
# .csv
# .csv
# .csv
# .csv
# .csv
# .csv
# .csv
# .csv
# .csv
# .exe
# .exe
# .msi
# .msi
# .exe
# .exe
# .png
# .png
# .png
# .png
# .png
# .webp
# .jpg
# .png
# .png
# .ipynb
# .ipynb
# .ipynb
# .ipynb
# .ipynb
# .ipynb
# .ipynb
# .ipynb
# .pdf
# .txt
# .txt
# .txt
# .md
# .md
# .md
# .zip
# .gz
# .gz
# .gz

# %% [markdown]
# ### 2. Crea un programa standalone (main.py, funciones.py, variables.py) que realice la tarea sin necesidad de Jupyter notebooks.

# %%
os.getcwd()
os.chdir(r'C:\Users\jlalo\Curso_Data\2026-02-BILBAO-FT-Data-Science\2-Data_Analysis\3-Sources\Archivos\Practica')
os.makedirs('orden', exist_ok=True)
for filename in ['main.py', 'funciones.py', 'variables.py']:
    open(os.path.join('orden', filename), 'a').close()
os.listdir('orden')
# Out:
# ['funciones.py', 'main.py', 'variables.py']
