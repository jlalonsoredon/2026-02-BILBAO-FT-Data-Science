# %% [markdown]
# ## Ejercicios de Matplotlib

# %% [markdown]
# 1. Importa pyplot, numpy y pandas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Sabemos que podemos pintar gráficas de dos formas: la figura incluye los ejes o teniendo figura y ejes por separado.
#
# Usando solo una figura, usa numpy para los valores del eje X entre 0 y 5.
#
# Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5).
#
# Elige la precisión en el eje X que desees.

# %%
#numpy para los valores del eje X entre 0 y 5
nums = np.linspace(0, 5, 100)
#una recta con pendiente positiva de 3 que pase por (0,0)
y1 = 3 * nums

#una recta con pendiente negativa de 3 que pase por (0,-5)
y2 = -3 * nums - 5

#dos graficas una a la izquierda y otra a la derecha
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

#graficamos la recta con pendiente positiva en el primer subplot
ax1.plot(nums, y1)

#graficamos la recta con pendiente negativa en el segundo subplot
ax2.plot(nums, y2)

plt.show()

# %% [markdown]
# 3. Fija el eje X entre 0 y 5 y el eje Y entre -15 y 15

# %%
nums = np.linspace(0, 5, 100)
y1 = 3 * nums
y2 = -3 * nums - 5

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(nums, y1)
ax1.set_xlim(0, 5)
ax1.set_ylim(-15, 15)

ax2.plot(nums, y2)
ax2.set_xlim(0, 5)
ax2.set_ylim(-15, 15)

plt.show()

# %% [markdown]
# 4. Llama al eje X "eje X", al eje Y "eje Y" y pon de títulos "recta sube" y "recta baja". Muestra dos etiquetas de ejeX pero solo una de eje Y.

# %%
nums = np.linspace(0, 5)
y1 = 3 * nums
y2 = -3 * nums - 5

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))

ax1.plot(nums, y1)
ax1.set_xlim(0, 5)
ax1.set_ylim(-15, 15)
ax1.set_xlabel("eje X")
ax1.set_ylabel("eje Y")
ax1.set_title("recta sube")

ax2.plot(nums, y2)
ax2.set_xlim(0, 5)
ax2.set_ylim(-15, 15)
ax2.set_xlabel("eje X")
ax2.set_title("recta baja")

plt.show()

# %% [markdown]
# 5. Usando una figura Y EJES POR SEPARADO, usa numpy para los valores del eje X entre 0 y 5. Pinta dos gráficas en dos cajas distintas, a la izquierda una recta con pendiente positiva de 3 que pase por (0,0) y a la derecha una recta con pendiente negativa de 3 que pase por (0,-5). Elige la precisión en el eje X que desees.

# %%
x
# Out:
# array([0.        , 0.55555556, 1.11111111, 1.66666667, 2.22222222,
#        2.77777778, 3.33333333, 3.88888889, 4.44444444, 5.        ])

# %%
y1
# Out:
# array([ 0.        ,  1.66666667,  3.33333333,  5.        ,  6.66666667,
#         8.33333333, 10.        , 11.66666667, 13.33333333, 15.        ])

# %%
y2
# Out:
# array([ -5.        ,  -6.66666667,  -8.33333333, -10.        ,
#        -11.66666667, -13.33333333, -15.        , -16.66666667,
#        -18.33333333, -20.        ])

# %%
fig, ax = plt.subplots(1,2)

ax[0].plot(x, y1)
ax[0].set_xlim(0,5)
ax[0].set_ylim(-15,15)
ax[0].set_xlabel("Eje x")
ax[0].set_ylabel("Eje y")
ax[0].set_title("Recta sube")

ax[1].plot(x, y2)
ax[1].set_xlim(0,5)
ax[1].set_ylim(-15,15)
ax[1].set_xlabel("Eje x")
ax[1].set_title("Recta baja");

# %% [markdown]
# 6. Crea una lista de coordenadas X: 20, 22, 24, 26, 28
# Crea una lista de coordenadas Y: 5, 15, -5, 20, 5
# Usa un gráfico de barras colocadas en X con alturas Y

# %%
x = [20, 22, 24, 26, 28]
y = [5, 15, -5, 20, 5]

fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(x, y)

plt.show()

# %% [markdown]
# 7. Crea un gráfico de barras. Pintamos la altura de un grupo de amigos, cada barra representa a una persona. Ana mide 160 cm, Luis mide 180 cm, Pedro mide 175 cm, Sofía mide 190 cm, Carmen mide 170 cm. Las barras serán verdes.
# Consejo: si no vas a tener que manipular especialmente los ejes, es más sencillo dejarlos dentro de la figura.

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, ax = plt.subplots(figsize=(10, 5))
ax.bar(altura.keys(), altura.values(), color="#41503C", edgecolor="#2E332D")
ax.set_xlabel("Amigos")
ax.set_ylabel("Altura (cm)")
ax.set_title("Altura de los amigos")
# Out:
# Text(0.5, 1.0, 'Altura de los amigos')

# %% [markdown]
# 8. Cambia el tamaño de la figura a (3,5)

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, ax = plt.subplots(figsize=(3, 5))
ax.bar(altura.keys(), altura.values(), color="#59CF35")
ax.set_xlabel("Amigos")
ax.set_ylabel("Altura (cm)")
ax.set_title("Altura de los amigos")

plt.show()

# %% [markdown]
# 9. Basándote en el gráfico anterior, borra la escala del eje Y (ya aparece en la altura)
# Pista: cuando plt.yticks() recibe una lista vacía no pinta el eje Y

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, ax = plt.subplots(figsize=(3, 5))
ax.bar(altura.keys(), altura.values(), color="#59CF35")
ax.set_xlabel("Amigos")
ax.set_ylabel("Altura (cm)")
ax.set_title("Altura de los amigos")
plt.yticks([])

plt.show()

# %% [markdown]
# 10. Prueba a hacer el gráfico con las barras en horizontal.

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, axh = plt.subplots(figsize=(5, 3))
#usamos barh para hacer un gráfico de barras horizontal en lugar de bar para que las barras sean horizontales
axh.barh(altura.keys(), altura.values(), color="#59CF35")
axh.set_xlabel("Altura (cm)")
axh.set_ylabel("Amigos")
axh.set_title("Altura de los amigos")
plt.show()

# %% [markdown]
# 11. Prueba a invertir los ejes con ax.invert_axis()
# Necesitarás tener los ejes disponibles fuera de la figura

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, axh = plt.subplots(figsize=(5, 3))
axh.barh(altura.keys(), altura.values(), color="#59CF35")
axh.set_xlabel("Altura (cm)")
axh.set_ylabel("Amigos")
axh.set_title("Altura de los amigos")

# Invertir el eje Y (los nombres aparecen en orden inverso)
axh.invert_yaxis()

plt.show()

# %% [markdown]
# 12. En el último gráfico, cambia el estilo a 'dark_background'

# %%
altura = {"Ana": 160, "Luis": 180, "Pedro": 175, "Sofia": 190, "Carmen": 170}
fig, axh = plt.subplots(figsize=(5, 3))
axh.barh(altura.keys(), altura.values(), color="#59CF35")
axh.set_xlabel("Altura (cm)")
axh.set_ylabel("Amigos")
axh.set_title("Altura de los amigos")
plt.style.use('dark_background')

# Invertir el eje Y (los nombres aparecen en orden inverso)
axh.invert_yaxis()

plt.show()

# %% [markdown]
# 13. Vamos a introducir pandas. Crea un DataFrame con las columnas "Year" de valores 2015, 2016, 2017, 2018, 2019 y la columna "Sold_items_A" de valores 1000, 3500, 4000, 5500, 7000

# %%
Year = [2015, 2016, 2017, 2018, 2019]
Sold_items_A = [1000, 3500, 4000, 5500, 7000]
df = pd.DataFrame({"Year": Year, "Sold_items_A": Sold_items_A})

# %% [markdown]
# 14. Ahora pintamos un gráfico de línea con las ventas respecto al año. Pon un título y etiquetas en los ejes.
# Cambia el estilo a 'seaborn-white'. La línea debe ser con rayas y verde.

# %%
plt.style.use('seaborn-v0_8-whitegrid')

fig, grafica = plt.subplots(figsize=(8, 5))
grafica.plot(df["Year"], df["Sold_items_A"], linestyle='--', color='green', linewidth=2, marker='o')
grafica.set_xlabel("Year")
grafica.set_ylabel("Sold items A")
grafica.set_title("Sales of item A over the years")
plt.show()

# %% [markdown]
# 15. Otro departamento B ha vendido en esos años 2000, 3100, 5000, 4000, 6000 unidades. Incluye esa columna en el DataFrame y pinta en la misma gráfica las dos líneas. B es una línea punteada y roja. Muestra una leyenda abajo a la derecha.

# %%
department_b = [2000, 3100, 5000, 4000, 6000]
df["Sold_items_B"] = department_b
df
# Out:
#    Year  Sold_items_A  Sold_items_B
# 0  2015          1000          2000
# 1  2016          3500          3100
# 2  2017          4000          5000
# 3  2018          5500          4000
# 4  2019          7000          6000

# %%
fig, grafica = plt.subplots(figsize=(8, 5))
grafica.plot(df["Year"], df["Sold_items_A"], linestyle='--', color='green', linewidth=2, marker='o', label="Department A")
grafica.plot(df["Year"], df["Sold_items_B"], linestyle='-.', color='red', linewidth=2, marker='o', label="Department B")
grafica.set_xlabel("Year")
grafica.set_ylabel("Sold items")
grafica.set_title("Sales of items A and B over the years")
grafica.legend(loc="upper left", fontsize=8, title="Departments", frameon=True, shadow=True, borderpad=1)
plt.show()

# %% [markdown]
# 16. Haz un scatter del departamento A usando __solo el DataFrame__.
# Pista: el propio DataFrame tiene un método plot.
# df.plot('columna X', 'columna Y', 'kind' = 'scatter)

# %%
fig, grafica = plt.subplots(figsize=(8, 5))
df.plot(x='Year', y='Sold_items_A', kind='scatter', ax=grafica, color='green', marker='o');

# %% [markdown]
# 17. Prueba a cambiar kind a 'pie'

# %%
fig, grafica = plt.subplots(figsize=(8, 5))
#hay que eliminar el marker
df.plot(x='Year', y='Sold_items_A', kind='pie', ax=grafica, color='green');

# %% [markdown]
# 18. Prueba a quitar la leyenda incluyendo legend igual a False, añade labels y quita la etiqueta en Y

# %%
fig, grafica = plt.subplots(figsize=(8, 5))
grafica.plot(df["Year"], df["Sold_items_A"], linestyle='--', color='green', linewidth=2, marker='o', label="Department A")
grafica.plot(df["Year"], df["Sold_items_B"], linestyle='-.', color='red', linewidth=2, marker='o', label="Department B")
grafica.set_xlabel("Year")
grafica.set_title("Sales of items A and B over the years")
#grafica.legend(False)

plt.show()

# %% [markdown]
# 19. Vamos a pintar un histograma de unas alturas generadas aleatoriamente. Crea 300 alturas entre 150 y 190 cm.

# %% [markdown]
# Pista: https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html

# %%
alruras = np.random.randint(150, 190, size=300)
print(alruras)
# Out:
# [163 187 176 173 164 173 172 174 164 171 187 168 188 179 161 166 157 156
#  152 155 176 151 166 171 182 172 162 162 168 168 157 185 182 167 175 187
#  158 153 173 157 172 183 173 189 177 160 169 181 189 161 159 158 166 164
#  154 166 185 152 162 150 170 187 174 163 187 162 172 151 160 178 189 160
#  172 154 169 163 165 169 171 170 158 163 186 163 151 179 174 171 187 160
#  175 186 154 159 159 176 168 151 174 177 158 154 186 176 157 172 189 165
#  163 188 177 172 164 183 185 152 186 151 170 150 179 187 182 166 183 172
#  162 175 164 187 180 153 184 165 180 170 153 187 159 151 165 187 160 164
#  154 181 156 153 169 170 180 176 177 169 151 180 176 174 168 180 153 170
#  160 166 153 162 183 163 177 184 167 174 163 163 181 163 184 151 163 182
#  170 167 165 180 183 159 184 176 166 156 177 164 157 181 150 185 170 181
#  177 180 178 157 173 185 152 179 186 167 155 184 154 176 153 187 152 162
#  154 172 155 187 168 171 153 180 175 183 178 173 167 186 175 174 172 155
#  178 172 181 150 178 154 158 150 174 183 178 165 174 159 184 176 160 165
#  159 187 154 176 169 152 189 174 151 153 176 156 189 152 154 182 176 162
#  155 181 188 185 176 158 182 167 152 165 161 156 158 171 171 158 159 163
#  156 189 167 168 169 157 158 151 172 159 176 169]

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.hist(alruras, bins=10, color="#59CF35", edgecolor="#2E332D")
ax.set_xlabel("Altura (cm)")
ax.set_ylabel("Frecuencia")
ax.set_title("Distribución de alturas aleatorias")
plt.show()

# %%
alturas_random = np.random.randint(150,190, 300)
serie_19 = pd.Series(alturas_random)
serie_19
# Out:
# 0      159
# 1      151
# 2      170
# 3      159
# 4      173
#       ...
# 295    154
# 296    162
# 297    188
# 298    170
# 299    182
# Length: 300, dtype: int32

# %%
alturas_random = np.random.randint(150,190, 1000)
serie_19 = pd.Series(alturas_random)
# serie_19

serie_19.plot(kind="hist", bins=10)
# Out:
# <Axes: ylabel='Frequency'>
